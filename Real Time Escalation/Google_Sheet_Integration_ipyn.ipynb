# %%
# !pip install "gspread==6.1.3"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: gspread
#     Found existing installation: gspread 6.0.2
#     Uninstalling gspread-6.0.2:
#       Successfully uninstalled gspread-6.0.2
# ...

# %%
sheets_link = "https://docs.google.com/spreadsheets/d/1dFptJN3y8M2lbQ6j3G3XkURAgrO3-FJjdMLk7ty5tsA/edit?usp=sharing"

# %%
#importing thorugh API key
import gspread

key = "gspread_api"
gc = gspread.api_key(key)

sh = gc.open_by_key("1dFptJN3y8M2lbQ6j3G3XkURAgrO3-FJjdMLk7ty5tsA")

# %%
import pandas as pd

worksheet = sh.sheet1

data = worksheet.get_all_values()

df_sheets = pd.DataFrame(data[1:], columns=data[0])

df_sheets
# Out:
#      Name Class Rollno
# 0   Pooja    12     23
# 1  Shruti     2     34
# 2    Riya     3     45

# %%
#importing through service account
from google.oauth2.service_account import Credentials

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
    'genaiprojectinfosys-8f8ae5cafe20.json',
    scopes=scopes
)

gc = gspread.authorize(credentials)

sh = gc.open_by_key("1dFptJN3y8M2lbQ6j3G3XkURAgrO3-FJjdMLk7ty5tsA")

# %%
worksheet = sh.sheet1

data = worksheet.get_all_values()

df_sheets = pd.DataFrame(data[1:], columns=data[0])

df_sheets
# Out:
#      Name Class Rollno
# 0   Pooja    12     23
# 1  Shruti     2     34
# 2    Riya     3    788
